# %% [markdown]
# # 03 — Feature Engineering
#
# Build customer-level features for segmentation (Task 2.1). Logic lives in `src/features/` and `src/data/joins.py`.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

import pandas as pd
from src.data.joins import build_customer_analytics_table, save_customer_base
from src.features.segmentation_features import create_segmentation_features, FEATURE_JUSTIFICATION

df = build_customer_analytics_table()
featured = create_segmentation_features(df)
save_customer_base(featured)
print(f'Customers: {len(featured):,}')
print(featured.columns.tolist())

# %%
pd.DataFrame(
    [{'feature': k, 'justification': v} for k, v in FEATURE_JUSTIFICATION.items()]
).head(15)
