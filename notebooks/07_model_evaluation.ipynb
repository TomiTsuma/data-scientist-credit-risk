# %% [markdown]
# # 07 — Model Evaluation
#
# Evaluate segmentation stability and API readiness.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

import json
import joblib
from src.config.config import Config

cfg = Config()
card = json.loads((cfg.models_dir / 'segmentation' / 'model_card.json').read_text())
print('Model:', card['model_type'], 'k=', card['n_clusters'])
pipeline = joblib.load(cfg.models_dir / 'segmentation' / 'kmeans_pipeline.joblib')
print('Pipeline steps:', [s[0] for s in pipeline.steps])
