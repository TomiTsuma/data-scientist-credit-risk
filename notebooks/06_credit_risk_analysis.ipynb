# %% [markdown]
# # 06 — Credit Risk Mitigation Analysis
#
# Task 2.4: actionable collections recommendations from the assessment dataset.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

import pandas as pd
from src.config.config import Config
from src.analysis.credit_insights import compute_collection_insights

cfg = Config()
df = pd.read_parquet(cfg.processed_dir / 'customer_features_base.parquet')
insights = compute_collection_insights(df)
for ins in insights[:3]:
    print(ins['id'], ins['title'])
    print('  Baseline:', ins['baseline'])
    print('  Action:', ins['action'])
    print()

# %%
df.groupby(['country_name', 'payment_type'])['is_in_arrears'].mean().unstack().round(3)
