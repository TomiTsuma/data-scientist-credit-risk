# %% [markdown]
# # 05 — Marketing Strategy (Kenya Premium Loan)
#
# Task 2.2: select two segments and define message + channel strategy.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('..').resolve()))

import pandas as pd
from src.config.config import Config
from src.analysis.marketing_strategy import top_two_segments, campaign_recommendations

cfg = Config()
segments = pd.read_parquet(cfg.processed_dir / 'customer_segments.parquet')
df = pd.read_parquet(cfg.processed_dir / 'customer_features_base.parquet')
df = df.merge(segments, on='customer_id')
top2 = top_two_segments(df, country='Kenya')
top2

# %%
for _, row in top2.iterrows():
    rec = campaign_recommendations(row)
    print('===', row['segment_name'], '===')
    for k, v in rec.items():
        print(f'{k}: {v}')
    print()
